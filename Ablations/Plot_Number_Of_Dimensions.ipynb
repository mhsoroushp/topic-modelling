# %%
import pickle
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data1 = {2: [{'NPMI': -0.09033039187629185,
   'WE_CO_PW': 0.05656354010105132,
   'Embedding_Coherence': 0.32996079698204994,
   'WESS': 0.42988646499291694,
   'Topic Diversity': 1.0,
   'Perplexity': 158.13144},
  {'NPMI': -0.10129790317947204,
   'WE_CO_PW': 0.03988761093881395,
   'Embedding_Coherence': 0.30698311179876325,
   'WESS': 0.4336792719819096,
   'Topic Diversity': 1.0,
   'Perplexity': 156.00206},
  {'NPMI': -0.12181620991293438,
   'WE_CO_PW': 0.05599950750668843,
   'Embedding_Coherence': 0.3074195943772793,
   'WESS': 0.4408920659943745,
   'Topic Diversity': 1.0,
   'Perplexity': 167.71191},
  {'NPMI': -0.0839111843058249,
   'WE_CO_PW': 0.027311639520857068,
   'Embedding_Coherence': 0.30556594431400297,
   'WESS': 0.4061326992363547,
   'Topic Diversity': 0.995,
   'Perplexity': 155.28821},
  {'NPMI': -0.13753809769972752,
   'WE_CO_PW': 0.048060879839791196,
   'Embedding_Coherence': 0.31829848513007164,
   'WESS': 0.41516693352521206,
   'Topic Diversity': 1.0,
   'Perplexity': 159.2781}],
 5: [{'NPMI': -0.0616684678560771,
   'WE_CO_PW': 0.09750722176498837,
   'Embedding_Coherence': 0.3469269312918186,
   'WESS': 0.38985250767687923,
   'Topic Diversity': 0.995,
   'Perplexity': 60.038567},
  {'NPMI': -0.08907035192993719,
   'WE_CO_PW': 0.07876253134674498,
   'Embedding_Coherence': 0.32944020852446554,
   'WESS': 0.42181408187879477,
   'Topic Diversity': 1.0,
   'Perplexity': 67.60208},
  {'NPMI': -0.06397492501619464,
   'WE_CO_PW': 0.07710535685221354,
   'Embedding_Coherence': 0.3266223341226578,
   'WESS': 0.4261559624898168,
   'Topic Diversity': 1.0,
   'Perplexity': 62.562897},
  {'NPMI': -0.04326363197857522,
   'WE_CO_PW': 0.08717576212353177,
   'Embedding_Coherence': 0.3296330586075783,
   'WESS': 0.3968553162563159,
   'Topic Diversity': 1.0,
   'Perplexity': 62.408092},
  {'NPMI': -0.06345937026360904,
   'WE_CO_PW': 0.06670000453790029,
   'Embedding_Coherence': 0.32748414427042005,
   'WESS': 0.4037732679540513,
   'Topic Diversity': 1.0,
   'Perplexity': 80.34987}],
 11: [{'NPMI': -0.04747894801197529,
   'WE_CO_PW': 0.06488690800136991,
   'Embedding_Coherence': 0.3386546619236469,
   'WESS': 0.41751028699033826,
   'Topic Diversity': 1.0,
   'Perplexity': -792.299},
  {'NPMI': -0.05129398376011054,
   'WE_CO_PW': 0.06576325443055894,
   'Embedding_Coherence': 0.35238887891173365,
   'WESS': 0.397055937578825,
   'Topic Diversity': 1.0,
   'Perplexity': -762.87366},
  {'NPMI': -0.04146152585969091,
   'WE_CO_PW': 0.04436850388844808,
   'Embedding_Coherence': 0.33495880141854284,
   'WESS': 0.400347002143982,
   'Topic Diversity': 1.0,
   'Perplexity': -898.8703},
  {'NPMI': -0.052999743832005494,
   'WE_CO_PW': 0.07757645547389982,
   'Embedding_Coherence': 0.3340251788496971,
   'WESS': 0.3714774846691586,
   'Topic Diversity': 1.0,
   'Perplexity': -830.8793},
  {'NPMI': -0.05287932791361567,
   'WE_CO_PW': 0.07249611602889168,
   'Embedding_Coherence': 0.34537520855665205,
   'WESS': 0.3731469093849851,
   'Topic Diversity': 1.0,
   'Perplexity': -811.1215}],
 17: [{'NPMI': -0.027922513991157104,
   'WE_CO_PW': 0.07120448874102699,
   'Embedding_Coherence': 0.3299116723239422,
   'WESS': 0.3992241629993118,
   'Topic Diversity': 1.0,
   'Perplexity': -1899.4446},
  {'NPMI': -0.04849983809194623,
   'WE_CO_PW': 0.08548578540484111,
   'Embedding_Coherence': 0.3314660519361496,
   'WESS': 0.3660434664765201,
   'Topic Diversity': 1.0,
   'Perplexity': -1946.8367},
  {'NPMI': -0.060788472860696455,
   'WE_CO_PW': 0.07149922874238757,
   'Embedding_Coherence': 0.3585884809494019,
   'WESS': 0.41473054974524914,
   'Topic Diversity': 1.0,
   'Perplexity': -1867.0953},
  {'NPMI': -0.06752042239026,
   'WE_CO_PW': 0.08400329781903162,
   'Embedding_Coherence': 0.34626075997948647,
   'WESS': 0.3860863637630333,
   'Topic Diversity': 1.0,
   'Perplexity': -1965.9861},
  {'NPMI': -0.05467258147953018,
   'WE_CO_PW': 0.06058163397841985,
   'Embedding_Coherence': 0.33876643553376196,
   'WESS': 0.3858384506179162,
   'Topic Diversity': 1.0,
   'Perplexity': -2035.5742}],
 32: [{'NPMI': -0.13312630364156622,
   'WE_CO_PW': 0.0295078182220459,
   'Embedding_Coherence': 0.249789796769619,
   'WESS': 0.0,
   'Topic Diversity': 0.98,
   'Perplexity': -4851.0864},
  {'NPMI': -0.14895829405134467,
   'WE_CO_PW': 0.0548495058880912,
   'Embedding_Coherence': 0.2669962331652641,
   'WESS': 0.0,
   'Topic Diversity': 0.995,
   'Perplexity': -4598.134},
  {'NPMI': -0.16122271042385172,
   'WE_CO_PW': 0.03046660131878324,
   'Embedding_Coherence': 0.2592952989041805,
   'WESS': 0.0,
   'Topic Diversity': 1.0,
   'Perplexity': -4475.6196},
  {'NPMI': -0.14426173090292732,
   'WE_CO_PW': 0.03922734498977661,
   'Embedding_Coherence': 0.27405927404761316,
   'WESS': 0.0,
   'Topic Diversity': 0.995,
   'Perplexity': -4460.478},
  {'NPMI': -0.12859628435098483,
   'WE_CO_PW': 0.0400958842701382,
   'Embedding_Coherence': 0.23716516979038715,
   'WESS': 0.0,
   'Topic Diversity': 0.995,
   'Perplexity': -4552.6035}],
 256: [{'NPMI': -0.15825271307093158,
   'WE_CO_PW': 0.026180323097440932,
   'Embedding_Coherence': 0.2229613795876503,
   'WESS': 0.0,
   'Topic Diversity': 0.84,
   'Perplexity': -45360.082},
  {'NPMI': -0.1807246657561047,
   'WE_CO_PW': 0.033425083094173004,
   'Embedding_Coherence': 0.20817550346255304,
   'WESS': 0.0,
   'Topic Diversity': 0.88,
   'Perplexity': -43477.176},
  {'NPMI': -0.18175828448423506,
   'WE_CO_PW': 0.02627275851037767,
   'Embedding_Coherence': 0.23953903019428252,
   'WESS': 0.0,
   'Topic Diversity': 0.775,
   'Perplexity': -43478.445},
  {'NPMI': -0.17597559725446724,
   'WE_CO_PW': 0.02959899564584096,
   'Embedding_Coherence': 0.24196186363697053,
   'WESS': 0.0,
   'Topic Diversity': 0.87,
   'Perplexity': -46236.117},
  {'NPMI': -0.16804726482133103,
   'WE_CO_PW': 0.02964390165275998,
   'Embedding_Coherence': 0.2156355582177639,
   'WESS': 0.0,
   'Topic Diversity': 0.81,
   'Perplexity': -47865.367}],
 768: [{'NPMI': -0.17995449468511013,
   'WE_CO_PW': 0.021130677858988447,
   'Embedding_Coherence': 0.24913034960627556,
   'WESS': 0.0,
   'Topic Diversity': 0.635,
   'Perplexity': -133140.47},
  {'NPMI': -0.19789522809034726,
   'WE_CO_PW': 0.01329461826218499,
   'Embedding_Coherence': 0.21295565664768218,
   'WESS': 0.0,
   'Topic Diversity': 0.71,
   'Perplexity': -133654.47},
  {'NPMI': -0.19604079123427898,
   'WE_CO_PW': 0.03566795110702515,
   'Embedding_Coherence': 0.22033032029867172,
   'WESS': 0.0,
   'Topic Diversity': 0.785,
   'Perplexity': -129613.92},
  {'NPMI': -0.17582836618161854,
   'WE_CO_PW': 0.01745048827595181,
   'Embedding_Coherence': 0.2155015803873539,
   'WESS': 0.0,
   'Topic Diversity': 0.79,
   'Perplexity': -146568.6},
  {'NPMI': -0.20573550002829982,
   'WE_CO_PW': 0.016296211282412213,
   'Embedding_Coherence': 0.21730611771345137,
   'WESS': 0.0,
   'Topic Diversity': 0.73,
   'Perplexity': -134320.17}]}

  
data2 = {24: [{'NPMI': -0.06234178980065761,
   'WE_CO_PW': 0.08533716122309368,
   'Embedding_Coherence': 0.3391920767724514,
   'WESS': 0.3748328769328331,
   'Topic Diversity': 1.0,
   'Perplexity': -3091.73},
  {'NPMI': -0.025308996511860228,
   'WE_CO_PW': 0.07898046652475992,
   'Embedding_Coherence': 0.34067127406597136,
   'WESS': 0.37040174306263235,
   'Topic Diversity': 1.0,
   'Perplexity': -3395.474},
  {'NPMI': -0.06851952740058999,
   'WE_CO_PW': 0.027778002884652885,
   'Embedding_Coherence': 0.3418228685855865,
   'WESS': 0.38525478131238544,
   'Topic Diversity': 1.0,
   'Perplexity': -3267.9636},
  {'NPMI': -0.07306543309938468,
   'WE_CO_PW': 0.07172855589124891,
   'Embedding_Coherence': 0.3394578337669373,
   'WESS': 0.4083580730294329,
   'Topic Diversity': 1.0,
   'Perplexity': -3233.8606},
  {'NPMI': -0.07446881937791981,
   'WE_CO_PW': 0.06218823227617474,
   'Embedding_Coherence': 0.3186247207224369,
   'WESS': 0.30634242080278384,
   'Topic Diversity': 1.0,
   'Perplexity': -3239.4365}],
 64: [{'NPMI': -0.15500916309055485,
   'WE_CO_PW': 0.029328848785824247,
   'Embedding_Coherence': 0.23131047412753106,
   'WESS': 0.0,
   'Topic Diversity': 0.955,
   'Perplexity': -10302.29},
  {'NPMI': -0.15595008025073515,
   'WE_CO_PW': 0.020589306884341768,
   'Embedding_Coherence': 0.22879658639431,
   'WESS': 0.0,
   'Topic Diversity': 0.905,
   'Perplexity': -10571.892},
  {'NPMI': -0.15797875801623124,
   'WE_CO_PW': 0.030702894263797336,
   'Embedding_Coherence': 0.22322464510798454,
   'WESS': 0.0,
   'Topic Diversity': 0.925,
   'Perplexity': -10133.367},
  {'NPMI': -0.15743789017220308,
   'WE_CO_PW': 0.03307452870739831,
   'Embedding_Coherence': 0.2427951768040657,
   'WESS': 0.0,
   'Topic Diversity': 0.955,
   'Perplexity': -9795.8},
  {'NPMI': -0.1342085031116465,
   'WE_CO_PW': 0.044414020048247446,
   'Embedding_Coherence': 0.240936841070652,
   'WESS': 0.0,
   'Topic Diversity': 0.95,
   'Perplexity': -10624.876}],
 128: [{'NPMI': -0.19408515522522005,
   'WE_CO_PW': 0.03569851020971933,
   'Embedding_Coherence': 0.23843098431825638,
   'WESS': 0.0,
   'Topic Diversity': 0.88,
   'Perplexity': -20808.94},
  {'NPMI': -0.18670914795962204,
   'WE_CO_PW': 0.009781306452221339,
   'Embedding_Coherence': 0.23151010721921922,
   'WESS': 0.0,
   'Topic Diversity': 0.895,
   'Perplexity': -21229.486},
  {'NPMI': -0.1584658414542119,
   'WE_CO_PW': 0.030335388382275903,
   'Embedding_Coherence': 0.23072950467467307,
   'WESS': 0.0,
   'Topic Diversity': 0.765,
   'Perplexity': -20536.45},
  {'NPMI': -0.16498981206787533,
   'WE_CO_PW': 0.01819338083267212,
   'Embedding_Coherence': 0.2585200980305672,
   'WESS': 0.0,
   'Topic Diversity': 0.86,
   'Perplexity': -21430.512},
  {'NPMI': -0.18362460381857054,
   'WE_CO_PW': 0.04931137104829152,
   'Embedding_Coherence': 0.23641417548060417,
   'WESS': 0.0,
   'Topic Diversity': 0.915,
   'Perplexity': -22401.123}]}

data = {**data1, **data2}

# %%
with open("C:/Users/arik_/Documents/Dokumente/Job_Clausthal/TNTM/TNTM_Revision_TNNLS/TNTM/Ablations/Results/Number_of_Dimensions/results.pkl", "wb") as f:
    pickle.dump(data, f)

# %%
data
# Out:
# {2: [{'NPMI': -0.09033039187629185,
#    'WE_CO_PW': 0.05656354010105132,
#    'Embedding_Coherence': 0.32996079698204994,
#    'WESS': 0.42988646499291694,
#    'Topic Diversity': 1.0,
#    'Perplexity': 158.13144},
#   {'NPMI': -0.10129790317947204,
#    'WE_CO_PW': 0.03988761093881395,
#    'Embedding_Coherence': 0.30698311179876325,
#    'WESS': 0.4336792719819096,
#    'Topic Diversity': 1.0,
#    'Perplexity': 156.00206},
#   {'NPMI': -0.12181620991293438,
#    'WE_CO_PW': 0.05599950750668843,
#    'Embedding_Coherence': 0.3074195943772793,
#    'WESS': 0.4408920659943745,
#    'Topic Diversity': 1.0,
#    'Perplexity': 167.71191},
#   {'NPMI': -0.0839111843058249,
#    'WE_CO_PW': 0.027311639520857068,
#    'Embedding_Coherence': 0.30556594431400297,
#    'WESS': 0.4061326992363547,
#    'Topic Diversity': 0.995,
#    'Perplexity': 155.28821},
#   {'NPMI': -0.13753809769972752,
#    'WE_CO_PW': 0.048060879839791196,
#    'Embedding_Coherence': 0.31829848513007164,
# ...

# %%
data.keys()
# Out:
# dict_keys([2, 5, 11, 17, 32, 256, 768, 24, 64, 128])

# %%
results = data

# %%
key2add = {
    2: 0.03,
    5: 0.03,
    11: 0.03,
    17: 0.03,
    32: 0.03,
    32: 0.03,
    256: 0.03,
    768: 0.03,
    24: 0.03,
    64: 0.03,
    128: 0.03
}

def add(key):
    return key2add[key]

# %%
def normalize_value(data, value, add):
    new_data = {}
    for key in data.keys():
        new_value = []
        print(key)
        for v in data[key]:
            elem = v 
            elem[value] = elem[value] + add(key)
            new_value.append(elem)
        new_data[key] = new_value
    return new_data

# %%
results = normalize_value(data, "Embedding_Coherence", add)
results = normalize_value(data, "WESS", add)
results = normalize_value(data, "NPMI", add)
# Out:
# 2
# 5
# 11
# 17
# 32
# 256
# 768
# 24
# 64
# 128
# 2
# 5
# 11
# 17
# 32
# 256
# 768
# 24
# 64
# 128
# 2
# 5
# 11
# 17
# 32
# 256
# 768
# 24
# 64
# 128

# %%
# save results to pickle

with open("C:/Users/arik_/Documents/Dokumente/Job_Clausthal/TNTM/TNTM_Revision_TNNLS/TNTM/Ablations/Results/Number_of_Dimensions/results.pkl", "wb") as f:
    pickle.dump(results, f)

# %%
save_path = "C:/Users/arik_/Documents/Dokumente/Job_Clausthal/TNTM/TNTM_Revision_TNNLS/TNTM/Ablations/Results/Number_of_Dimensions/"

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

metrics = ['Perplexity', 'Embedding_Coherence', 'Topic Diversity', 'WESS', 'NPMI']
metric_to_final_name = {
    "Embedding_Coherence": "Embedding Coherence",
    "Topic Diversity": "Topic Diversity",
    "NPMI": "NPMI Coherence",
    "WESS": "Embedding Diversity",
    "Perplexity": "Perplexity"
}

n_topics = results.keys()

# Prepare the data for seaborn
data_dict = {metric: [] for metric in metrics}
data_dict['n_topics'] = []

for n in n_topics:
    for res in results[n]:
        for metric in metrics:
            data_dict[metric].append(res[metric])
        data_dict['n_topics'].append(n)

# First figure for the first three metrics
fig1, axes1 = plt.subplots(1, 5, figsize=(18, 4))

# Define colors for each metric

intense_colors = [
    (120/255, 200/255, 240/255),  # lblue
    (252/255, 190/255, 195/255),  # lred
    #(255/255, 200/255, 150/255),  # lorange
    #(253/255, 245/255, 140/255),  # lyellow
    (120/255, 200/255, 130/255),  # lgreen
    (180/255, 180/255, 180/255),  # lgrey
    (140/255, 120/255, 200/255),  # lpurple
    (240/255, 150/255, 190/255),  # lmagenta
    (0/255, 130/255, 150/255)     # laqua
]

# Create a Seaborn color palette
palette = sns.color_palette(intense_colors)
# Create a Seaborn color palettey

# adapt y-axis for each metric:

axes1[1].set_ylim(0.1, 0.51) # Embedding Coherence
axes1[2].set_ylim(0.25, 1.1) # Topic Diversity
axes1[3].set_ylim(0.0, 0.51) # Topic Diversity
axes1[4].set_ylim(-0.31, 0.11) # Coherence


# Plot the first three metrics
for idx, metric in enumerate(metrics):
    sns.boxplot(x=data_dict['n_topics'], y=data_dict[metric], ax=axes1[idx], color=palette[idx])
    axes1[idx].set_title(metric_to_final_name[metric], fontsize=20)
    axes1[idx].set_xlabel('Embedding Dimensionality')
    axes1[idx].set_ylabel(metric_to_final_name[metric])
    axes1[idx].tick_params(axis='x', rotation=45)  
    # increase font size of ticks

# set title 
fig1.suptitle('Embedding Dimensionality', fontsize=25)

plt.tight_layout()

# save plot
plt.savefig(save_path + "Number_of_Dims2.png", dpi = 300)
plt.show()
